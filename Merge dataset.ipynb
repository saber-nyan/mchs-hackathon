# %%
legit = {}
with open('./legit_train', 'rt') as f:
    for line in f:
        legit[line[:-1]] = 0
with open('./legit_test', 'rt') as f:
    for line in f:
        legit[line[:-1]] = 0
print(legit)
len(legit)
# Out:
# {'btnews24.com.bd': 0, 'ademaltan.com.tr': 0, 'ahedu.gov.cn': 0, 'firstory.me': 0, 'major-nissan.ru': 0, 'torplay.ir': 0, 'sudutnusantara.com': 0, 'articlexpress.co.uk': 0, 'kashmirfight.wordpress.com': 0, 'crackedlink.com': 0, 'traiborg.com': 0, 'pglearn.ir': 0, 'reachmail.com': 0, 'zlotxo.com': 0, 'baridamakine.com.tr': 0, 'theaterfestival.ir': 0, 'studyinaustralia.gov.au': 0, 'aeon.co': 0, 'soft-na-russkom.ru': 0, 'xn--b1advnalp3h.xn--p1ai': 0, 'skandhanshi.com': 0, 'gfgalliance.com': 0, 'coreflutterwaveprod.com': 0, 'hdagaotawiil.blogspot.com': 0, 'postprotector.com': 0, 'bergrath-shop.de': 0, 'kaktaktravel.ru': 0, 'mimesisedizioni.it': 0, 'khb.com': 0, 'tusnumerosrd.com': 0, 'thirtyeightvisuals.com': 0, 'yatirimadestek.gov.tr': 0, 'ecuador221.com.ec': 0, 'tuftandpaw.com': 0, 'shortlinkterbaik.com': 0, 'gtimg.cn': 0, 'emailjeet.com': 0, 'ambrsoft.com': 0, 'easymc.io': 0, 'riga-trikotazh.ru': 0, 'alfaic.ua': 0, 'musicdiffusion.com': 0, 'adampreiser.com': 0, 'napoleon.sg': 0, 'pure
# ...

# %%
dga = {}
with open('./dga_train', 'rt') as f:
    for line in f:
        meh = line.split('\t')
        dga[meh[0]] = 1
        if len(dga) >= 13000:
            break
#ith open('./dga_test', 'rt') as f:
#   for line in f:
#       meh = line.split('\t')
#       dga[meh[0]] = 1
print(dga)
len(dga)
# Out:
# {'vxahkhhujhuzpvzsnmapg.info': 1, 'rgbcsxpkmrjcpcsa.net': 1, 'yzftixoxrccw.net': 1, 'mvrfpydlqgtuntvkvvdjx.org': 1, 'svzbpswakulmmvwq.net': 1, 'ihyzspcoriwce.biz': 1, 'julhvifzvte.net': 1, 'omjxlnnvvqjehfocjls.net': 1, 'gkuhnhifsvtyvwnefwzoj.org': 1, 'xpxgxqzwtmpsahz.org': 1, 'ownlllocrluetmghuhmlzwd.info': 1, 'dgnxhlbmqbovufc.net': 1, 'xmvozhywoqhbaykynkwjja.net': 1, 'cpoyrnooysmm.biz': 1, 'qzxpcgsltowftunhhumdfcotz.info': 1, 'easoibnxudzybv.biz': 1, 'oxalywwzssqffbhhf.com': 1, 'nlmdkmgr.org': 1, 'qpdvbkiwdqkpa.biz': 1, 'bqwzoutirbwodgvyj.biz': 1, 'jmatvoqnkiwkxkx.org': 1, 'iqyoipxkixm.org': 1, 'uskzhaynxqdeoadlqsx.org': 1, 'afgatnzvhwrxhvrqt.info': 1, 'txgqdmcmqrkmxsovk.org': 1, 'sgrfhjfiturfdgo.info': 1, 'miyitmdqlviihgiefshhuevqc.com': 1, 'rvrstwjvjbcqrmasmdspgqgz.com': 1, 'pqpzcovvyqvgvicfthjl.net': 1, 'dvboqsnvuxqruy.org': 1, 'gkdqnjntmmrqsaveebg.info': 1, 'pdwreuihwdvtlmw.biz': 1, 'uewjxgjtzxzcmio.org': 1, 'kbnjqyqfpwfrgiij.com': 1, 'zfymaoqoqonxx.net': 1, 'lytrpnlfgrswnzqncyp
# ...

# %%
dataset = dict(**dga, **legit)
print(dataset)
# Out:
# {'vxahkhhujhuzpvzsnmapg.info': 1, 'rgbcsxpkmrjcpcsa.net': 1, 'yzftixoxrccw.net': 1, 'mvrfpydlqgtuntvkvvdjx.org': 1, 'svzbpswakulmmvwq.net': 1, 'ihyzspcoriwce.biz': 1, 'julhvifzvte.net': 1, 'omjxlnnvvqjehfocjls.net': 1, 'gkuhnhifsvtyvwnefwzoj.org': 1, 'xpxgxqzwtmpsahz.org': 1, 'ownlllocrluetmghuhmlzwd.info': 1, 'dgnxhlbmqbovufc.net': 1, 'xmvozhywoqhbaykynkwjja.net': 1, 'cpoyrnooysmm.biz': 1, 'qzxpcgsltowftunhhumdfcotz.info': 1, 'easoibnxudzybv.biz': 1, 'oxalywwzssqffbhhf.com': 1, 'nlmdkmgr.org': 1, 'qpdvbkiwdqkpa.biz': 1, 'bqwzoutirbwodgvyj.biz': 1, 'jmatvoqnkiwkxkx.org': 1, 'iqyoipxkixm.org': 1, 'uskzhaynxqdeoadlqsx.org': 1, 'afgatnzvhwrxhvrqt.info': 1, 'txgqdmcmqrkmxsovk.org': 1, 'sgrfhjfiturfdgo.info': 1, 'miyitmdqlviihgiefshhuevqc.com': 1, 'rvrstwjvjbcqrmasmdspgqgz.com': 1, 'pqpzcovvyqvgvicfthjl.net': 1, 'dvboqsnvuxqruy.org': 1, 'gkdqnjntmmrqsaveebg.info': 1, 'pdwreuihwdvtlmw.biz': 1, 'uewjxgjtzxzcmio.org': 1, 'kbnjqyqfpwfrgiij.com': 1, 'zfymaoqoqonxx.net': 1, 'lytrpnlfgrswnzqncyp
# ...

# %%
with open('big_dataset', 'wt') as f:
    for k, v in dataset.items():
        f.write(f'{k}\t{v}\n')
